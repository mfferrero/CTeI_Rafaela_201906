# %% [markdown]
# # Workshop: Informática Aplicada
# ## Machine Learning y Data Science: un enfoque práctico
# Rafaela - 5 y 6 de junio
#
# Ariel Rossanigo - Mariano Ferrero

# %% [markdown]
# # Bienvenidos ! Este documento es un Jupyter Notebook

# %% [markdown]
# ## Qué es?
#
# - Es parte del proyecto Jupyter: un proyecto open source que fomenta la programación interactiva en múltiples lenguajes (Python, R, Ruby, C#, etc.). Contiene un editor de texto, los Notebooks, administrador de "kernels", manejo de usuarios, etc.
# - Jupyter Notebook: es una aplicación web donde se pueden crear documentos interactivos que combinan texto, código, gráficas, imágenes, ecuaciones, etc.

# %% [markdown]
# # Un Notebook se compone de celdas y cada una de ellas es de un tipo: código o Markdown (texto, imágenes, HTML, etc.)
#
# Esta es de tipo Markdown

# %%
print('Esta es de tipo código (code)')
# Out:
# Esta es de tipo código (code)

# %% [markdown]
# ### Más ejemplos:

# %%
print('Hola mundo!')
# Out:
# Hola mundo!

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

n = 100000
x = np.random.standard_normal(n)
y = 2.0 + 3.0 * x + 4.0 * np.random.standard_normal(n)
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

fig, axs = plt.subplots(ncols=2, sharey=True, figsize=(7, 4))
fig.subplots_adjust(hspace=0.5, left=0.07, right=0.93)
ax = axs[0]
hb = ax.hexbin(x, y, gridsize=50, cmap='inferno')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("Hexagon binning")
cb = fig.colorbar(hb, ax=ax)
cb.set_label('counts')

ax = axs[1]
hb = ax.hexbin(x, y, gridsize=50, bins='log', cmap='inferno')
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("With a log color scale")
cb = fig.colorbar(hb, ax=ax)
cb.set_label('log10(N)')

plt.show()

# %% [markdown]
# ### Ecuaciones utilizando LaTex

# %% [markdown]
# $$\int_\Omega \nabla u \cdot \nabla v~dx = \int_\Omega fv~dx$$

# %% [markdown]
# # Desde la barra de herramientas podemos agregar, mover, o eliminar celdas, cambiar su tipo, ejecutarlas, etc.

# %% [markdown]
# # Son muy potentes, pero hay que tener cuidado !
